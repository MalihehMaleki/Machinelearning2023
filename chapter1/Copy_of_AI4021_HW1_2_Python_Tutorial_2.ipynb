# %% [markdown]
# <a href="https://colab.research.google.com/github/MalihehMaleki/Machinelearning2023/blob/main/chapter1/Copy_of_AI4021_HW1_2_Python_Tutorial_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Problem 1:** Create a NumPy array of 20 random integers between 1 and 100. Calculate the mean, median, and standard deviation of the array.

# %%
import numpy as np
#create and sort the randomlist
np.random.seed(0)
x = np.random.randint(1, 100, 20)
x.sort()
print("x = " , x)

#calculate the  median
print(" Median = ", np.median(x))

#calculate the  mean
print(" Mean = ", np.mean(x))

#calculate the standard deviation
SD = np.std(x)
print("standard deviation  = ", SD)
# Out:
# x =  [10 13 22 37 40 45 47 48 59 65 66 68 68 71 84 88 88 89 89 89]
#  Median =  65.5
#  Mean =  59.3
# standard deviation  =  25.088044961694408

# %% [markdown]
# **Problem 2:** Create a Pandas DataFrame with three columns - 'Name', 'Age', and 'City' - and at least five rows of data. Perform a basic data exploration by displaying the first 3 rows, the last 2 rows, and a summary of statistics for the 'Age' column.

# %%
import pandas as pd
#create a dictionari\y to store data
data = {
    "Name": ["Mali","Aida","Setayesh","Sahar","Tahoora"],
    "Age": [22,21,22,21,21],
    "City": ["Tehran","Qom","Hamedan","Tehran","Qom"]
}
#creat dataframe
df = pd.DataFrame(data)
#print the dataframe
print("DataFrame :")
print(df)
# Out:
# DataFrame :
#        Name  Age     City
# 0      Mali   22   Tehran
# 1      Aida   21      Qom
# 2  Setayesh   22  Hamedan
# 3     Sahar   21   Tehran
# 4   Tahoora   21      Qom

# %% [markdown]
# **Problem 3:** Create a bar chart using Matplotlib to visualize the following data: Monthly sales for a store (January to May). Use appropriate labels and titles for the chart.

# %%
from pandas._libs.tslibs.offsets import MonthBegin
import matplotlib.pyplot as plt
import numpy as np

# create some data
Month = ["January","February","March","April","MAy"]
number = [158,263,200,147,189]

#create a bar plot

plt.bar(Month,number,color='blue')  # customize bar color
plt.xlabel('Month')
plt.ylabel('number of sales')
plt.title('bar plot of monthly sales')
plt.grid(axis='y', linestyle ='--',alpha = 0.8)

#display values on top of bars
for i, v in enumerate(number):
  plt.text(i,v+1,str(v),ha='center',va='bottom')

#shoe the plot
plt.show()

# %% [markdown]
# **Problem 4:** Create two NumPy arrays, 'arr1' and 'arr2', both of size 5x5 with random integer values. Perform element-wise addition, subtraction, multiplication, and division between the two arrays.

# %%
import numpy as np
np.random.seed()
arr1 = np.random.randint(0,50,(5,5))
arr2 = np.random.randint(0,50,(5,5))
print('arr1:')
print(arr1)
print('\narr2:')
print(arr2)
addition = arr1 + arr2
subtraction = arr1 - arr2
multiplication = arr1*arr2
division = arr1/arr2

print('\naddition:')
print(addition)
print('\nsubtraction:')
print(subtraction)
print('\nmultiplication:')
print(multiplication)
print('\ndivision:')
print(division)
# Out:
# arr1:
# [[ 6 34 19 24 10]
#  [ 7 41 26 13 49]
#  [14 42 22 24  1]
#  [42 43 28 27 29]
#  [46 45  4  8  0]]
#
# arr2:
# [[37 34 14 26 45]
#  [ 5  5 15 34 48]
#  [31 43 14 13 14]
#  [17 19 36  2 28]
#  [ 2 27  1 43 31]]
#
# addition:
# [[43 68 33 50 55]
#  [12 46 41 47 97]
#  [45 85 36 37 15]
#  [59 62 64 29 57]
#  [48 72  5 51 31]]
#
# subtraction:
# [[-31   0   5  -2 -35]
#  [  2  36  11 -21   1]
#  [-17  -1   8  11 -13]
#  [ 25  24  -8  25   1]
#  [ 44  18   3 -35 -31]]
#
# multiplication:
# [[ 222 1156  266  624  450]
#  [  35  205  390  442 2352]
#  [ 434 1806  308  312   14]
#  [ 714  817 1008   54  812]
#  [  92 1215    4  344    0]]
#
# division:
# [[ 0.16216216  1.          1.35714286  0.92307692  0.22222222]
#  [ 1.4         8.2         1.73333333  0.38235294  1.02083333]
#  [ 0.4516129   0.97674419  1.57142857  1.84615385  0.07142857]
#  [ 2.47058824  2.26315789  0.77777778 13.5         1.03571429]
#  [23.          1.66666667  4.          0.18604651  0.        ]]

# %% [markdown]
# **Problem 5:** Given a Pandas DataFrame with information about employees, filter and display only the employees who are older than 30 years.

# %%
import pandas as pd
#create a DateFrame
data = {
    "name" : ['Mamad','Ali','Saeed','Sara','Sahar'],
    "Age" : [25,44,31,36,29],
    "gender" : ['M','M','M','F','F']
}
df = pd.DataFrame(data)
#display the employees older than 30
subset_age_gt_30 = df[df["Age"] > 30]
print("subset of rows with age > 30 :\n")
print(subset_age_gt_30)
# Out:
# subset of rows with age > 30 :
#
#     name  Age gender
# 1    Ali   44      M
# 2  Saeed   31      M
# 3   Sara   36      F

# %% [markdown]
# **Problem 6:** Create a scatter plot using Matplotlib to visualize a dataset of 100 random (x, y) coordinates. Label the axes appropriately and give the plot a title.

# %%
import matplotlib.pyplot as plt
import numpy as np
#generate random data
x = np.random.rand(100)
y = np.random.rand(100)

#create a scatter plot
plt.scatter(x,y,c='blue',marker = 'o',label = 'random points')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('visualize a dataset of 100 random point')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# **Problem 7:** Create two NumPy matrices, 'matrix1' (2x3) and 'matrix2' (3x4), with random values. Perform matrix multiplication between the two matrices.

# %%
import numpy as np
matrix1 = np.random.randint(0,50,(2,3))
matrix2 = np.random.randint(0,50,(3,4))
print('matrix1 = \n')
print(matrix1)
print('\nmatrix2 = \n')
print(matrix2)
print('\nmultiplication = \n')
print(matrix1.dot(matrix2))
# Out:
# matrix1 =
#
# [[35 43  6]
#  [32 43 19]]
#
# matrix2 =
#
# [[42  8 19 29]
#  [44 26 46 46]
#  [32  1  3 10]]
#
# multiplication =
#
# [[3554 1404 2661 3053]
#  [3844 1393 2643 3096]]

# %% [markdown]
# **Problem 8:** Given a Pandas DataFrame containing sales data, calculate and display the total sales for each product category.

# %%
import pandas as pd
#create dataframe
data = {
    'Product Category' : ['Books','Clothing','Car','Food','Car','Books','Food','Car'],
    'Sales Amount' : [300,890,58,1950,68,593,1265,45]
}
sales_df = pd.DataFrame(data)
category_sales = sales_df.groupby('Product Category')['Sales Amount'].sum().reset_index()
print(category_sales)
# Out:
#   Product Category  Sales Amount
# 0            Books           893
# 1              Car           171
# 2         Clothing           890
# 3             Food          3215

# %% [markdown]
# **Problem 9:** Create a line chart using Matplotlib to visualize the population growth of a city over 10 years. Label the axes and provide a title.

# %%
import matplotlib.pyplot as plt
import numpy as np
#create some data
a = np.random.randint(10000,100000,10)
y = a
x = [2014,2015,2016,2017,2018,2019,2020,2021,2022,2023]
#plot the data
plt.plot(x,y,label="population",color = "blue")
plt.xlabel("year")
plt.ylabel("population")
plt.title("population growth")
plt.grid(True)
plt.show()

# %% [markdown]
# **Problem 10:** Given a Pandas DataFrame containing information about students, add a new column 'Grade' based on the following criteria:
# * If 'Score' >= 90, Grade is 'A'
# * If 'Score' >= 80, Grade is 'B'
# * If 'Score' >= 70, Grade is 'C'
# * If 'Score' < 70, Grade is 'D'

# %%
import pandas as pd
import numpy as np
#create a dataframe
data = {
    'name' : ['Fateme','Hasti','Ali','Javad'],
    'score' : [65,84,98,72]
}
df = pd.DataFrame(data)

#add a new column
df['Grade'] = ['A','B','C','D']

#update the Grade culumn
df.loc[df['score'] >= 90, 'Grade'] = 'A'
df.loc[(df['score'] >= 80) & (df['score'] < 90), 'Grade'] = 'B'
df.loc[(df['score'] >= 70) & (df['score'] < 80), 'Grade'] = 'C'
df.loc[df['score'] < 70, 'Grade'] = 'D'

print(df)
# Out:
#      name  score Grade
# 0  Fateme     65     D
# 1   Hasti     84     B
# 2     Ali     98     A
# 3   Javad     72     C

# %% [markdown]
# **Problem 11:** You are given a dataset containing monthly sales data for three products (A, B, and C) over a two-year period. Your task is to perform various data analysis tasks using NumPy, Pandas, and Matplotlib.
#
#
# *   Dataset:
#
# ```
# import pandas as pd
#
# data = {
#     'Month': pd.date_range(start='2021-01-01', periods=24, freq='M'),
#     'Product A Sales': [500, 480, 600, 750, 900, 850, 920, 1100, 1300, 1350, 1500, 1450, 1550, 1600, 1650, 1600, 1500, 1400, 1600, 1700, 1800, 1750, 1850, 1900],
#     'Product B Sales': [300, 320, 400, 450, 500, 580, 700, 750, 820, 900, 950, 980, 1050, 1100, 1150, 1200, 1250, 1300, 1350, 1400, 1500, 1600, 1550, 1700],
#     'Product C Sales': [200, 210, 250, 280, 320, 350, 380, 400, 420, 440, 460, 480, 500, 520, 540, 560, 580, 600, 620, 640, 660, 680, 700, 720]
# }
#
# sales_df = pd.DataFrame(data)
# ```
# *  Tasks:
# 1. Calculate and display the total sales for each product over the two-year period.
#
# 2. Calculate and display the average monthly sales for each product.
#
# 3. Find the month with the highest sales for each product, and display the product and the sales value for that month.
#
# 4. Calculate and display the percentage change in sales for each product from January to December in the second year (2022).
#
# 5. Create a line chart using Matplotlib to visualize the monthly sales data for each product over the two-year period. Label the axes and provide a title for the chart.
#
# 6. Calculate the correlation between Product A and Product B sales. Is there a strong correlation between these two products? Display the correlation coefficient.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = {
    'Month': pd.date_range(start = '2021-01-01 ', periods = 24, freq = 'M'),
    'Product A sales' : [500,480,600,750,900,850,920,1100,1300,1350,1500,1450,1550,1600,1650,1600,1500,1400,1600,1700,1800,1750,1850,1900],
    'Product B sales' : [300,320,400,450,500,580,700,750,820,900,950,980,1050,1100,1150,1200,1250,1300,1350,1400,1500,1600,1550,1700],
    'Product C sales' : [200,210,250,280,320,350,380,400,420,440,460,480,500,520,540,560,580,600,620,640,660,680,700,720]
}
sales_df = pd.DataFrame(data)

#Task1
total_sales = sales_df.sum()
print("total sales :")
print(total_sales)
print()

#Task2
average_sales = sales_df.mean()
print("Average Monthly Sales: ")
print(average_sales)
print()

#Task3
highest_sales_month = sales_df.idxmax()
highest_sales = sales_df.max()
print("Month with Highest Sales: ")
print(highest_sales_month)
print("Sales Value: ")
print(highest_sales)
print()

#Task4
sales_2021 = sales_df.loc[0:11][['Product A sales','Product B sales','Product C sales']].sum()
sales_2022 = sales_df.loc[12:23][['Product A sales','Product B sales','Product C sales']].sum()
percentage_change = ((sales_2022 - sales_2021)/sales_2021) * 100
print("percentage change in sales in 2022: ")
print(percentage_change)
print()

#Task5
sales_df.set_index('Month', inplace = True)
sales_df.plot()
plt.xlabel('Month')
plt.ylabel('Sales')
plt.grid(True, linestyle='--')
plt.show()

#Task6
correlation = sales_df[['Product A sales','Product B sales']].corr().iloc[0,1]
print("correlation between product A and product B sales: ")
print(f"correlation coefficient: {correlation:.2f}")
# Out:
# <ipython-input-8-7fab87444b93>:14: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   total_sales = sales_df.sum()
# <ipython-input-8-7fab87444b93>:20: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   average_sales = sales_df.mean()
# total sales :
# Product A sales    31600
# Product B sales    23800
# Product C sales    11510
# dtype: int64
#
# Average Monthly Sales:
# Product A sales    1316.666667
# Product B sales     991.666667
# Product C sales     479.583333
# dtype: float64
#
# Month with Highest Sales:
# Month              23
# Product A sales    23
# Product B sales    23
# Product C sales    23
# dtype: int64
# Sales Value:
# Month              2022-12-31 00:00:00
# Product A sales                   1900
# Product B sales                   1700
# Product C sales                    720
# dtype: object
#
# percentage change in sales in 2022:
# Product A sales     70.085470
# Product B sales    111.111111
# Product C sales     74.701671
# dtype: float64
# correlation between product A and product B sales:
# correlation coefficient: 0.95
